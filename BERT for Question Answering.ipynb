# %% [markdown]
# ## Practice 4 - Question & Answering with BERT

# %% [markdown]
# ### 실습 4.1 - Load SQuAD Raw Data with JSON
# ### SQuAD 데이터 살펴보기

# %%
import os
import json

filename = "/kaggle/input/2024-1-nlp-4/train-v2.json"

with open(filename, "r", encoding='utf-8') as reader:
    input_data = json.load(reader)["data"]
    
for entry in input_data:
    for paragraph in entry["paragraphs"]:
        context = paragraph['context']
        print(context)
        print()
        
        for qa in paragraph['qas']:
            is_impossible = qa['is_impossible']

            if not is_impossible:
                answer = qa['answers'][0]
                original_answer = answer['text']
                answer_start = answer['answer_start']
                
            qid=qa['id'],
            question=qa['question'],
                
            print(qid, question, answer)
        
    
        break
    break
# Out:
# Beyoncé Giselle Knowles-Carter (/biːˈjɒnseɪ/ bee-YON-say) (born September 4, 1981) is an American singer, songwriter, record producer and actress. Born and raised in Houston, Texas, she performed in various singing and dancing competitions as a child, and rose to fame in the late 1990s as lead singer of R&B girl-group Destiny's Child. Managed by her father, Mathew Knowles, the group became one of the world's best-selling girl groups of all time. Their hiatus saw the release of Beyoncé's debut album, Dangerously in Love (2003), which established her as a solo artist worldwide, earned five Grammy Awards and featured the Billboard Hot 100 number-one singles "Crazy in Love" and "Baby Boy".
#
# ('56be85543aeaaa14008c9063',) ('When did Beyonce start becoming popular?',) {'text': 'in the late 1990s', 'answer_start': 269}
# ('56be85543aeaaa14008c9065',) ('What areas did Beyonce compete in when she was growing up?',) {'text': 'singing and dancing', 'answer_start': 207}
# ('56be85543aeaaa14008c9066',) ("When did Beyonce leave Destiny's Child and become a solo singer?",) {'text': '2003', 'answer_start': 526}
# ('56bf6b0f3aeaaa14008c9601',) ('In what city and state did Beyonce  grow up? ',) {'text': 'Houston, Texas', 'answer_start': 166}
# ('56bf6b0f3aeaaa14008c9602',) ('In which decade did Beyonce become famous?',) {'text': 'late 1990s', 'answer_start': 276}
# ('56bf6b0f3aeaaa14008c9603',) ('In what R&B group was she the lead singer?',) {'text': "Destiny's Child", 'answer_start': 320}
# ('56bf6b0f3aeaaa14008c9604',) ('What album made her a worldwide known artist?',) {'text': 'Dangerously in Love', 'answer_start': 505}
# ('56bf6b0f3aeaaa14008c9605',) ("Who managed the Destiny's Child group?",) {'text': 'Mathew Knowles', 'answer_start': 360}
# ('56d43c5f2ccc5a1400d830a9',) ('When did Beyoncé rise to fame?',) {'text': 'late 1990s', 'answer_start': 276}
# ('56d43c5f2ccc5a1400d830aa',) ("What role did Beyoncé have in Destiny's Child?",) {'text': 'lead singer', 'answer_start': 290}
# ('56d43c5f2ccc5a1400d830ab',) ('What was the first album Beyoncé released as a solo artist?',) {'text': 'Dangerously in Love', 'answer_start': 505}
# ('56d43c5f2ccc5a1400d830ac',) ('When did Beyoncé release Dangerously in Love?',) {'text': '2003', 'answer_start': 526}
# ('56d43c5f2ccc5a1400d830ad',) ('How many Grammy awards did Beyoncé win for her first solo album?',) {'text': 'five', 'answer_start': 590}
# ('56d43ce42ccc5a1400d830b4',) ("What was Beyoncé's role in Destiny's Child?",) {'text': 'lead singer', 'answer_start': 290}
# ('56d43ce42ccc5a1400d830b5',) ("What was the name of Beyoncé's first solo album?",) {'text': 'Dangerously in Love', 'answer_start': 505}

# %% [markdown]
# ### 실습 4.2 - SQuAD Dataset Class 생성 (from raw data to tokenized version)

# %% [markdown]
# 주석 달아라

# %%
import os
import json
import torch
from torch.utils.data import Dataset, TensorDataset

# import module we'll need to import our custom module
from shutil import copyfile

# copy our file into the working directory (make sure it has .py suffix)
copyfile(src = "/kaggle/input/2024-1-nlp-4/feature.py", dst = "/kaggle/working/feature.py")
from feature import convert_examples_to_features

# whitespace 여부 체크 함수
def is_whitespace(c):
    if c == " " or c == "\t" or c == "\r" or c == "\n" or ord(c) == 0x202F:
        return True
    return False

# 하나의 SQuAD 예제를 저장하는 클래스
class SquadExample():
    def __init__(self, qid, context, question, answer, start, end, is_impossible):
        self.qid = qid
        self.context = context
        self.question = question
        self.answer = answer
        self.start = start
        self.end = end
        self.is_impossible = is_impossible
        
    def __repr__(self):
        #return self.context[self.start:self.end]
        #if self.context[self.start:self.end] != self.answer:
        #    return 'NA!! {} - {}'.format(self.context[self.start:self.end], answer)
        return 'id:{}  question:{}...  answer:{}...  is_impossible:{}'.format(
            self.qid,
            self.question[:10],
            self.answer[:10],
            self.is_impossible)

# SQuAD 데이터셋을 PyTorch Dataset으로 변환하는 클래스        
class SquadDataset(Dataset):
    def __init__(self, path, tokenizer, is_train=True, is_inference=False):
        '''
        path: SquadDataset 데이터셋 위치
        tokenizer: Squad 데이터셋을 토크나이징할 토크나이저, ex) BertTokenizer
        is_train: SquadDataset을 정의하는 목적이 모델 학습용일 경우 True, 그렇지 않으면 False
        is_inference: SquadDataset을 정의하는 목적이 인퍼런스용일 경우 True, 그렇지 않으면 False
        '''
        
        if is_train:
            filename = os.path.join(path, 'train-v2.json')
        else:
            if is_inference:
                filename = os.path.join(path, 'test-v2.json')
            else:
                filename = os.path.join(path, 'dev-v2.json')

        cached_features_file = os.path.join(os.path.dirname(filename), 'cached_{}_64.cache'.format('train' if is_train else 'valid'))
        #cached_examples_file = os.path.join(os.path.dirname(filename), 'cached_example_{}_64.cache'.format('train' if is_train else 'valid'))

        if os.path.exists(cached_features_file):
            print('cache file exists')
            self.features = torch.load(cached_features_file)
        else:
            print('cache file does not exist')

            with open(filename, "r", encoding='utf-8') as reader:
                input_data = json.load(reader)["data"]

            self.examples = []
            n_o_e = 10
            for entry in input_data[:n_o_e]:
#             for entry in input_data:
                for paragraph in entry["paragraphs"]:
                    context = paragraph['context']
                    
                    doc_tokens = []
                    char_to_word_offset = []
                    prev_is_whitespace = True
                    for c in context:
                        if is_whitespace(c):
                            prev_is_whitespace = True
                        else:
                            if prev_is_whitespace:
                                doc_tokens.append(c)
                            else:
                                doc_tokens[-1] += c
                            prev_is_whitespace = False
                        char_to_word_offset.append(len(doc_tokens) - 1)
                            
                            
                    for qa in paragraph['qas']:
                        is_impossible = qa['is_impossible']
                        
                        if not is_impossible:
                            answer = qa['answers'][0]
                            original_answer = answer['text']
                            answer_start = answer['answer_start']
                            
                            answer_length = len(original_answer)
                            start_pos = char_to_word_offset[answer_start]
                            end_pos = char_to_word_offset[answer_start + answer_length - 1]

                            answer_end = answer_start + len(original_answer)
                        else:
                            original_answer = ''
                            start_pos = 1
                            end_pos = -1

                        example = SquadExample(
                            qid=qa['id'],
                            context=doc_tokens,
                            question=qa['question'],
                            answer=original_answer,
                            start=start_pos,
                            end=end_pos,
                            is_impossible=is_impossible)
                        self.examples.append(example)
            print('examples: {}'.format(len(self.examples)))

            self.features = convert_examples_to_features(
                examples=self.examples,
                tokenizer=tokenizer,
                max_seq_length=384,
                doc_stride=128,
                max_query_length=64,
                is_training=True if not is_inference else False)
            print('is_training: {}'.format(True if not is_inference else False))

            # torch.save(self.examples, cached_examples_file)
            # torch.save(self.features, cached_features_file)

        '''
        # Convert to Tensors and build dataset
        all_input_ids = torch.tensor([f.input_ids for f in self.features], dtype=torch.long)
        all_input_mask = torch.tensor([f.input_mask for f in self.features], dtype=torch.long)
        all_segment_ids = torch.tensor([f.segment_ids for f in self.features], dtype=torch.long)
        all_cls_index = torch.tensor([f.cls_index for f in self.features], dtype=torch.long)
        all_p_mask = torch.tensor([f.p_mask for f in self.features], dtype=torch.float)
        if is_train:
            all_start_positions = torch.tensor([f.start_position for f in self.features], dtype=torch.long)
            all_end_positions = torch.tensor([f.end_position for f in self.features], dtype=torch.long)
            dataset = TensorDataset(all_input_ids, all_input_mask, all_segment_ids,
                                    all_start_positions, all_end_positions,
                                    all_cls_index, all_p_mask)
        else:
            all_example_index = torch.arange(all_input_ids.size(0), dtype=torch.long)
            dataset = TensorDataset(all_input_ids, all_input_mask, all_segment_ids, all_example_index, all_cls_index, all_p_mask)
        return dataset
        '''


    def __len__(self):
        return len(self.features)

    def __getitem__(self, idx):
        return self.features[idx]

# %% [markdown]
# ### 실습 4.3 - SQuAD DataLoader 생성 (from raw data to tokenized version)

# %%
import torch
from torch.utils.data import DataLoader

class SquadDataLoader(DataLoader):
    def __init__(self, dataset, batch_size, is_inference=False, shuffle=True):
        '''
        dataset: SquadDataset으로 정의한 데이터셋 객체
        batch_size: 배치 사이즈
        is_inference: SquadDataLoader를 인퍼런스 목적으로 사용할 경우 True, 그렇지 않으면 False
        shuffle: 데이터의 순서를 섞을 경우 True, 그렇지 않으면 False
        '''
        self.is_inference = is_inference
        super().__init__(dataset, collate_fn=self.squad_collate_fn, batch_size=batch_size, shuffle=shuffle)
        
    def squad_collate_fn(self, features):
        all_input_ids = torch.tensor([f.input_ids for f in features], dtype=torch.long)
        all_input_mask = torch.tensor([f.input_mask for f in features], dtype=torch.long)
        all_segment_ids = torch.tensor([f.segment_ids for f in features], dtype=torch.long)
        all_cls_index = torch.tensor([f.cls_index for f in features], dtype=torch.long)
        all_p_mask = torch.tensor([f.p_mask for f in features], dtype=torch.float)

        # return 6 tensors
        if self.is_inference:
            all_example_index = torch.arange(all_input_ids.size(0), dtype=torch.long)
            return all_input_ids, all_input_mask, all_segment_ids, all_cls_index, all_p_mask, all_example_index
        # return 7 tensors
        else:
            all_start_positions = torch.tensor([f.start_position for f in features], dtype=torch.long)
            all_end_positions = torch.tensor([f.end_position for f in features], dtype=torch.long)
            return all_input_ids, all_input_mask, all_segment_ids, all_cls_index, all_p_mask, all_start_positions, all_end_positions

# %% [markdown]
# ### 실습 4.4 Load Dataset

# %%
import torch
from tqdm import tqdm, trange
from torch import nn
from torch.utils.data import DataLoader

path = "/kaggle/input/2024-1-nlp-4/"

from transformers import BertTokenizer

print("Tokenizer Loading")
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)

print("Dataset Loading")
train_dataset = SquadDataset(path, tokenizer, is_train=True) # 153,000

print("Data Loader")
train_dataloader = SquadDataLoader(train_dataset, batch_size=32, is_inference=False, shuffle=True)
# Out:
# Tokenizer Loading
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Dataset Loading
# cache file does not exist
# examples: 4719
# 100%|██████████| 4719/4719 [00:53<00:00, 87.75it/s]
# is_training: True
# Data Loader

# %% [markdown]
# ### 실습 4.5 - Load Pre-trained BERT
# ### 과제 4.1 - BERT for Question Answering 모델 이해하고 설명하기 / Tokenizer 변경해보기
#
# #### BERT for Question Answering 참고
# #### https://huggingface.co/docs/transformers/v4.41.0/en/model_doc/bert#transformers.BertForQuestionAnswering
#
# #### BERT Tokenizer 참고
# #### https://huggingface.co/docs/transformers/v4.41.0/en/model_doc/bert#transformers.BertTokenizer

# %%
# pytoch model import from huggingface
from transformers import BertTokenizer, BertForQuestionAnswering, AdamW

# GPU 이용 방법 - Notebook Option - Session Options - ACCELRATOR 설정 (GPU P100)
# .cuda() 옵션을 제거하면 cpu에서도 학습 가능
model = BertForQuestionAnswering.from_pretrained('bert-base-uncased').cuda()

model.train()
# Out:
# model.safetensors:   0%|          | 0.00/440M [00:00<?, ?B/s]
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# BertForQuestionAnswering(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#   )
#   (qa_outputs): Linear(in_features=768, out_features=2, bias=True)
# )

# %% [markdown]
# ### 실습 4.6 - Fine-tuning with your SQuAD Dataset

# %% [markdown]
# 주석 달아

# %%
# train fucntion
def train(model, dataloader, optimizer):
    tbar = tqdm(dataloader, desc='Training', leave=True) # dataloader에서 배치를 받아올 tqdm progress bar를 설정합니다.    
    total_loss = 0.0
    for i, batch in enumerate(tbar):
        optimizer.zero_grad() # 각 배치마다 기존 gradient를 0으로 초기화합니다.
        
        # cls_index와 p_mask는 XLNet 모델에 사용되므로 BERT에서는 사용하지 않는다.
        input_ids, input_mask, segment_ids, cls_index, p_mask, start_positions, end_positions = batch
        
        # to cuda (gpu 사용 시)
        input_ids = input_ids.cuda()
        input_mask = input_mask.cuda()
        segment_ids = segment_ids.cuda()
        start_positions = start_positions.cuda()
        end_positions = end_positions.cuda()
        
        # train model (모델을 훈련합니다.)
        #out = model(input_ids=input_ids, attention_mask=attention_mask, labels=labels)
        inputs = {
            'input_ids': input_ids,
            'token_type_ids': segment_ids,
            'attention_mask': input_mask,
        }
        out = model(**inputs, start_positions=start_positions, end_positions=end_positions)
        loss = out.loss
        
        # loss를 back propagation합니다.
        loss.backward()
        optimizer.step()
        
        # 누적 loss를 계산
        total_loss += loss.data.item()
        tbar.set_description("Average Loss = {:.4f})".format(total_loss/(i+1)))

# %%
""" 원래 코드
Train (Fine-tune) your BERT with SQuAD dataset
"""

optimizer = AdamW(model.parameters(), lr = 2e-5, eps = 1e-8)
loss = nn.CrossEntropyLoss()
n_epoch = 10

# actual training
for i in range(n_epoch):
    train(model, train_dataloader, optimizer)

# save model
torch.save(model.state_dict(), 'squad_model.bin')
# Out:
# /opt/conda/lib/python3.10/site-packages/transformers/optimization.py:457: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Average Loss = 3.1071): 100%|██████████| 151/151 [02:59<00:00,  1.19s/it]
# Average Loss = 1.3501): 100%|██████████| 151/151 [02:59<00:00,  1.19s/it]
# Average Loss = 0.8971): 100%|██████████| 151/151 [02:59<00:00,  1.19s/it]
# Average Loss = 0.6309): 100%|██████████| 151/151 [02:59<00:00,  1.19s/it]
# Average Loss = 0.4566): 100%|██████████| 151/151 [02:59<00:00,  1.19s/it]
# Average Loss = 0.3580): 100%|██████████| 151/151 [02:59<00:00,  1.19s/it]
# Average Loss = 0.2862): 100%|██████████| 151/151 [02:59<00:00,  1.19s/it]
# Average Loss = 0.2369): 100%|██████████| 151/151 [02:59<00:00,  1.19s/it]
# Average Loss = 0.1984): 100%|██████████| 151/151 [02:59<00:00,  1.19s/it]
# Average Loss = 0.1722): 100%|██████████| 151/151 [02:59<00:00,  1.19s/it]

# %%
# """ 13시간 돌린 모델
# Train (Fine-tune) your BERT with SQuAD dataset
# """

# import torch
# from transformers import BertTokenizer, BertForQuestionAnswering, AdamW

# model = BertForQuestionAnswering.from_pretrained('bert-base-uncased').cuda()

# model.load_state_dict(torch.load('/kaggle/input/squad-model-ep10/squad_model_ep10.bin'))

# %% [markdown]
# ### 과제 4.2 Inference 및 Evaluate
#
# - 파인튜닝을 마치고 dev-v2.json 파일을 불러와 Inference를 위한 코드를 실행한다.
# - 예측한 span과 정답 span을 비교해본다.
# - F1을 이용하여 dev-v2.json의 샘플 1000개를 대상으로 예측한 span과 정답 span을 평가하는 코드를 작성한다.
#
# 아래 평가용 코드 참고
#
# - https://github.com/jinkilee/hello-transformer/blob/master/research/chapter4/squad/run_evaluate.py
# - https://github.com/jinkilee/hello-transformer/blob/master/research/chapter4/squad/evaluate.py

# %%
valid_dataset = SquadDataset(path, tokenizer, is_train=False) # 11,873
valid_dataloader = SquadDataLoader(valid_dataset, batch_size=32, is_inference=False, shuffle=True)
# Out:
# cache file does not exist
# examples: 3366
# 100%|██████████| 3366/3366 [00:41<00:00, 81.42it/s]
# is_training: True

# %%
# 학습된 모델이 예측한 결과와 주어진 validation 데이터셋과 비교해본다.
def inference(model, dataloader, device):
    model.eval()
    predictions = []
    
    with torch.no_grad():
        for batch in dataloader:
            input_ids, input_mask, segment_ids, start_positions, end_positions, cls_index, p_mask = batch
            
            input_ids = input_ids.to(device)
            input_mask = input_mask.to(device)
            segment_ids = segment_ids.to(device)
            
            outputs = model(input_ids=input_ids, attention_mask=input_mask, token_type_ids=segment_ids)
            start_logits = outputs.start_logits
            end_logits = outputs.end_logits
            
            start_pred = torch.argmax(start_logits, dim=1)
            end_pred = torch.argmax(end_logits, dim=1)
            
            for i in range(len(start_pred)):
                predictions.append((start_pred[i].item(), end_pred[i].item(), input_ids[i].tolist()))
    
    return predictions

# %%
from collections import Counter

def evaluate_prediction(prediction, ground_truth):
    prediction_tokens = prediction.split()
    ground_truth_tokens = ground_truth.split()
    
    common = Counter(prediction_tokens) & Counter(ground_truth_tokens)
    num_same = sum(common.values())
    if num_same == 0:
        return 0
    
    precision = 1.0 * num_same / len(prediction_tokens)
    recall = 1.0 * num_same / len(ground_truth_tokens)
    f1 = (2 * precision * recall) / (precision + recall)
    
    return f1

# %%
import torch

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Fine-tuned된 데이터셋을 평가한다.
def evaluate(model, dataloader, examples, device):
    predictions = inference(model, dataloader, device)
    
    f1_scores = []
    for i, (pred_start, pred_end, _) in enumerate(predictions[:1000]):  # 샘플 1000개 평가
        example = examples[i]
        context = example.context
        true_answer = example.answer
        
        pred_answer = ' '.join(context[pred_start:pred_end+1])
        
        # 예측한 span과 정답 span 비교
        print(f"Example {i+1}:")
        print(f"Predicted Answer: {pred_answer}")
        print(f"True Answer: {true_answer}")
        print()
        
        f1 = evaluate_prediction(pred_answer, true_answer)
        f1_scores.append(f1)
    
    avg_f1 = sum(f1_scores) / len(f1_scores)
    print(f"Average F1 Score: {avg_f1:.4f}")

def main():
    # 모델 정의
    model = BertForQuestionAnswering.from_pretrained("bert-base-uncased", num_labels=2).to(device)
    model.load_state_dict(torch.load("/kaggle/working/squad_model.bin"))
    model.eval()
    
    tokenizer = BertTokenizer.from_pretrained('bert-base-uncased', do_lower_case=True)
    evaluate(model, valid_dataloader, valid_dataset.examples, device)

if __name__ == "__main__":
    main()
# Out:
# Some weights of BertForQuestionAnswering were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['qa_outputs.bias', 'qa_outputs.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Example 1:
# Predicted Answer: in the 10th and 11th centuries gave their name
# True Answer: France
#
# Example 2:
# Predicted Answer: West
# True Answer: 10th and 11th centuries
#
# Example 3:
# Predicted Answer:
# True Answer: Denmark, Iceland and Norway
#
# Example 4:
# Predicted Answer: raiders and pirates from Denmark,
# True Answer: Rollo
#
# Example 5:
# Predicted Answer:
# True Answer: 10th century
#
# Example 6:
# Predicted Answer: leader Rollo,
# True Answer:
#
# Example 7:
# Predicted Answer:
# True Answer:
#
# Example 8:
# Predicted Answer: of the
# True Answer:
#
# Example 9:
# Predicted Answer:
# True Answer:
#
# Example 10:
# Predicted Answer: even the Near East. The Normans were famed for their martial spirit and eventually for their Christian piety, becoming exponents of the Catholic orthodoxy into which they assimilated. They adopted the Gallo-Romance language of the Frankish land they settled, their dialect becoming known as Norman, Normaund or Norman French, an important literary language. The Duchy of Normandy, which they formed by treaty with the French crown, was a great fief of medieval France, and under Richard I of Normandy was forged into a cohesive and formidable principality in feudal tenure. The Normans are noted both for their
# True Answer: William the Conqueror
#
# Example 11:
# Predicted Answer: orthodoxy into which
# True Answer: Richard I
#
# Example 12:
# Predicted Answer: the Frankish land they settled, their
# True Answer: Catholic
#
# Example 13:
# Predicted Answer: exponents of
# True Answer:
#
# Example 14:
# Predicted Answer: Gallo-Romance language of
# True Answer:
#
# Example 15:
# Predicted Answer: becoming known as Norman, Normaund
# True Answer:
#
# Example 16:
# Predicted Answer: Battle of Hastings in 1066. Norman cultural and military influence spread from these new European centres to the Crusader states of the Near East, where their prince
# True Answer:
#
# Example 17:
# Predicted Answer: they formed by treaty with the French
# True Answer:
#
# Example 18:
# Predicted Answer: of Normant, modern French normand, which is
# True Answer: Viking
#
# Example 19:
# Predicted Answer:
# True Answer: 9th century
#
# Example 20:
# Predicted Answer: itself borrowed
# True Answer:
#
# Example 21:
# Predicted Answer:
# True Answer:
#
# Example 22:
# Predicted Answer: roughly
# True Answer: 911
#
# Example 23:
# Predicted Answer: King Charles
# True Answer: King Charles III
#
# Example 24:
# Predicted Answer: Duchy of Normandy, which
# True Answer: Seine
#
# Example 25:
# Predicted Answer:
# True Answer:
#
# Example 26:
# Predicted Answer:
# True Answer:
#
# Example 27:
# Predicted Answer: III of
# True Answer:
#
# Example 28:
# Predicted Answer: Francia and
# True Answer:
#
# Example 29:
# Predicted Answer: settlers.
# True Answer: Rollo
#
# Example 30:
# Predicted Answer: east (Roumois and
# True Answer:
#
# Example 31:
# Predicted Answer: Swedes,
# True Answer:
#
# Example 32:
# Predicted Answer: language that
# True Answer: Catholicism
#
# Example 33:
# Predicted Answer:
# True Answer: north
#
# Example 34:
# Predicted Answer: into the regional language that survives today.
# True Answer:
#
# Example 35:
# Predicted Answer:
# True Answer:
#
# Example 36:
# Predicted Answer: survives today.
# True Answer:
#
# Example 37:
# Predicted Answer:
# True Answer: fighting horsemen
#
# Example 38:
# Predicted Answer:
# True Answer:
#
# Example 39:
# Predicted Answer: their lineage
# True Answer:
#
# Example 40:
# Predicted Answer: Norman rulers
# True Answer:
#
# Example 41:
# Predicted Answer: act
# True Answer: Seljuk Turks
#
# Example 42:
# Predicted Answer: Soon after the Normans began to enter Italy, they entered the Byzantine Empire and then Armenia, fighting against the Pechenegs, the Bulgars, and especially the Seljuk Turks. Norman mercenaries were first encouraged to come to the south by the Lombards to act against the Byzantines, but they soon fought in Byzantine service in Sicily. They were prominent alongside Varangian and Lombard contingents in the Sicilian campaign of George Maniaces in 1038–40. There is debate whether the Normans in Greek service actually were from Norman Italy, and it now seems likely only a few came
# True Answer:
#
# Example 43:
# Predicted Answer: against the Byzantines, but they soon fought in Byzantine service in Sicily.
# True Answer:
#
# Example 44:
# Predicted Answer: prominent
# True Answer:
#
# Example 45:
# Predicted Answer: contingents
# True Answer:
#
# Example 46:
# Predicted Answer: One
# True Answer: 1050s
#
# Example 47:
# Predicted Answer: the 1050s. By
# True Answer: 1060s
#
# Example 48:
# Predicted Answer: with support from
# True Answer: Alexius Komnenos
#
# Example 49:
# Predicted Answer:
# True Answer:
#
# Example 50:
# Predicted Answer: Byzantine duke of
# True Answer:
#
# Example 51:
# Predicted Answer: mercenaries serving
# True Answer:
#
# Example 52:
# Predicted Answer:
# True Answer:
#
# Example 53:
# Predicted Answer:
# True Answer: Afranji
#
# Example 54:
# Predicted Answer: the upper Euphrates valley in northern
# True Answer: Oursel
#
# Example 55:
# Predicted Answer: to 1074,
# True Answer: Turkish forces
#
# Example 56:
# Predicted Answer: Anatolia. Later, many took
# True Answer:
#
# Example 57:
# Predicted Answer: far eastern Anatolia. Later, many took up
# True Answer:
#
# Example 58:
# Predicted Answer:
# True Answer:
#
# Example 59:
# Predicted Answer: service with the Armenian
# True Answer:
#
# Example 60:
# Predicted Answer: seeking out western European warriors. The Raoulii were descended from an Italo-Norman named Raoul, the Petraliphae were descended from a Pierre d'Aulps, and that group of Albanian clans known as the Maniakates were descended from Normans who served under George Maniaces in the Sicilian expedition of 1038.
# True Answer: Norman mercenary
#
# Example 61:
# Predicted Answer:
# True Answer:
#
# Example 62:
# Predicted Answer: Byzantine emperors were seeking out western European warriors. The Raoulii were descended from an Italo-Norman named Raoul, the Petraliphae were descended from a Pierre d'Aulps, and that group of Albanian clans known as the Maniakates were descended from Normans who served under George Maniaces in the Sicilian expedition of 1038.
# True Answer:
#
# Example 63:
# Predicted Answer: in
# True Answer:
#
# Example 64:
# Predicted Answer: count of
# True Answer: Robert Guiscard
#
# Example 65:
# Predicted Answer: with Croatia and the
# True Answer: 1082
#
# Example 66:
# Predicted Answer: The Albanian
# True Answer: 30,000
#
# Example 67:
# Predicted Answer: conquering the Balkan
# True Answer:
#
# Example 68:
# Predicted Answer: Corfu and attacked Dyrrachium
# True Answer:
#
# Example 69:
# Predicted Answer: for
# True Answer:
#
# Example 70:
# Predicted Answer: continued his campaign conquering the Balkan peninsula as a
# True Answer:
#
# Example 71:
# Predicted Answer: avail.
# True Answer: Deabolis
#
# Example 72:
# Predicted Answer: had
# True Answer: Bohemond
#
# Example 73:
# Predicted Answer:
# True Answer: Deabolis
#
# Example 74:
# Predicted Answer: them. With their help, the Normans secured the Arbanon passes and opened their way to
# True Answer:
#
# Example 75:
# Predicted Answer:
# True Answer:
#
# Example 76:
# Predicted Answer: Arbanon
# True Answer:
#
# Example 77:
# Predicted Answer: The
# True Answer: 1185
#
# Example 78:
# Predicted Answer:
# True Answer: Dyrrachium
#
# Example 79:
# Predicted Answer:
# True Answer: the Adriatic
#
# Example 80:
# Predicted Answer:
# True Answer:
#
# Example 81:
# Predicted Answer:
# True Answer:
#
# Example 82:
# Predicted Answer:
# True Answer:
#
# Example 83:
# Predicted Answer:
# True Answer: King Ethelred II
#
# Example 84:
# Predicted Answer: date.
# True Answer: Duke Richard II
#
# Example 85:
# Predicted Answer: by Sweyn Forkbeard. His stay in Normandy
# True Answer: Normandy
#
# Example 86:
# Predicted Answer: ties
# True Answer: Sweyn Forkbeard
#
# Example 87:
# Predicted Answer: this, Ethelred fled to Normandy in 1013,
# True Answer:
#
# Example 88:
# Predicted Answer:
# True Answer:
#
# Example 89:
# Predicted Answer: Ethelred II
# True Answer:
#
# Example 90:
# Predicted Answer: earl
# True Answer: Harthacnut
#
# Example 91:
# Predicted Answer: When finally Edward the Confessor returned from his father's refuge in 1041, at the invitation of his half-brother Harthacnut, he brought with him a Norman-educated mind. He also brought many Norman counsellors and fighters, some of whom established an English cavalry force. This concept never really took root, but it is a typical example of the attitudes of Edward. He appointed Robert of Jumièges archbishop of Canterbury and made Ralph the Timid earl of Hereford. He invited his brother-in-law Eustace II, Count of
# True Answer: 1041
#
# Example 92:
# Predicted Answer: the Timid earl of Hereford.
# True Answer: Robert of Jumièges
#
# Example 93:
# Predicted Answer:
# True Answer:
#
# Example 94:
# Predicted Answer: mind. He also brought
# True Answer:
#
# Example 95:
# Predicted Answer:
# True Answer:
#
# Example 96:
# Predicted Answer: homage to the King
# True Answer: Battle of Hastings
#
# Example 97:
# Predicted Answer:
# True Answer: William II
#
# Example 98:
# Predicted Answer: to the King
# True Answer: 1066
#
# Example 99:
# Predicted Answer: with it the title of King—an important
# True Answer: Anglo-Saxons
#
# Example 100:
# Predicted Answer: a single Normans culture and many had lands on both sides of the channel. Early Norman kings
# True Answer:
#
# Example 101:
# Predicted Answer: sides of the channel. Early
# True Answer:
#
# Example 102:
# Predicted Answer:
# True Answer:
#
# Example 103:
# Predicted Answer:
# True Answer:
#
# Example 104:
# Predicted Answer: themselves as English. The Anglo-Norman language became distinct from the Latin language, something that was the subject of some humour by Geoffrey Chaucer. The Anglo-Norman language was eventually absorbed into the Anglo-Saxon language of their subjects (see Old English) and influenced it, helping (along
# True Answer: Modern English
#
# Example 105:
# Predicted Answer:
# True Answer:
#
# Example 106:
# Predicted Answer: turn
# True Answer:
#
# Example 107:
# Predicted Answer: Norse language of the earlier Anglo-Norse settlers and the Latin used by the church) in the development
# True Answer:
#
# Example 108:
# Predicted Answer: Wexford
# True Answer: 1169
#
# Example 109:
# Predicted Answer: invasion at
# True Answer: Ireland
#
# Example 110:
# Predicted Answer:
# True Answer: Irish
#
# Example 111:
# Predicted Answer:
# True Answer:
#
# Example 112:
# Predicted Answer:
# True Answer:
#
# Example 113:
# Predicted Answer: (De)
# True Answer:
#
# Example 114:
# Predicted Answer: ships. Malcolm submitted, paid homage to William
# True Answer: Edgar
#
# Example 115:
# Predicted Answer: riding as far as Abernethy where he met up with his fleet of ships. Malcolm submitted,
# True Answer: King Malcolm III of Scotland
#
# Example 116:
# Predicted Answer: as Abernethy where he
# True Answer: 1072
#
# Example 117:
# Predicted Answer:
# True Answer: Duncan
#
# Example 118:
# Predicted Answer: Malcolm
# True Answer:
#
# Example 119:
# Predicted Answer:
# True Answer:
#
# Example 120:
# Predicted Answer: southern borders. William invaded Scotland in 1072, riding as
# True Answer:
#
# Example 121:
# Predicted Answer: the "Davidian Revolution". Having spent time at the court
# True Answer: Sybilla of Normandy
#
# Example 122:
# Predicted Answer: as Robert the Bruce, as well as founding a considerable number of the Scottish clans. King David I of Scotland, whose elder brother Alexander I had married Sybilla of Normandy, was instrumental in introducing Normans and Norman culture to Scotland, part of the process some scholars call the "Davidian Revolution". Having spent
# True Answer: Norman
#
# Example 123:
# Predicted Answer: but a few, and including
# True Answer:
#
# Example 124:
# Predicted Answer: some scholars call the "Davidian
# True Answer:
#
# Example 125:
# Predicted Answer:
# True Answer: Hereford
#
# Example 126:
# Predicted Answer:
# True Answer: the Welsh
#
# Example 127:
# Predicted Answer:
# True Answer: Edward the Confessor
#
# Example 128:
# Predicted Answer:
# True Answer:
#
# Example 129:
# Predicted Answer:
# True Answer:
#
# Example 130:
# Predicted Answer: Norman interference. Norman words, such
# True Answer: Wales
#
# Example 131:
# Predicted Answer: in Cheshire. These
# True Answer:
#
# Example 132:
# Predicted Answer:
# True Answer:
#
# Example 133:
# Predicted Answer: Moorish lands, but
# True Answer: 1018
#
# Example 134:
# Predicted Answer: a state for himself from Moorish lands, but failed. In 1064, during
# True Answer: William of Montreuil
#
# Example 135:
# Predicted Answer: They were major
# True Answer:
#
# Example 136:
# Predicted Answer: The
# True Answer:
#
# Example 137:
# Predicted Answer: de Tosny travelled to
# True Answer:
#
# Example 138:
# Predicted Answer: carved out a Norman principality in Antioch.
# True Answer:
#
# Example 139:
# Predicted Answer: by Bohemond of Taranto
# True Answer: 1097
#
# Example 140:
# Predicted Answer: Tancred with
# True Answer: Tancred
#
# Example 141:
# Predicted Answer: and his nephew Tancred with
# True Answer: Jerusalem
#
# Example 142:
# Predicted Answer: facto leader
# True Answer:
#
# Example 143:
# Predicted Answer: passage through Asia Minor. After the successful Siege
# True Answer:
#
# Example 144:
# Predicted Answer: the island, which would be under Western European domination for the following 380 years.
# True Answer: 380 years
#
# Example 145:
# Predicted Answer:
# True Answer:
#
# Example 146:
# Predicted Answer: history of
# True Answer:
#
# Example 147:
# Predicted Answer: and
# True Answer: a storm
#
# Example 148:
# Predicted Answer:
# True Answer: Berengaria
#
# Example 149:
# Predicted Answer: dispersed the fleet.
# True Answer: 1191
#
# Example 150:
# Predicted Answer:
# True Answer: Isaac Komnenos
#
# Example 151:
# Predicted Answer: south coast of Cyprus, together with
# True Answer:
#
# Example 152:
# Predicted Answer:
# True Answer:
#
# Example 153:
# Predicted Answer: with a large fleet in order to reach Acre. But a storm dispersed the fleet. After some searching, it was discovered that the boat carrying his sister and his fiancée Berengaria was anchored on the south coast of Cyprus, together with the wrecks of several other ships, including the treasure ship. Survivors of the wrecks had been taken prisoner by the island's despot Isaac Komnenos. On 1 May 1191, Richard's fleet arrived in the port of Limassol on Cyprus. He ordered Isaac to release the prisoners and the treasure. Isaac refused, so Richard landed his troops and took Limassol.
# True Answer:
#
# Example 154:
# Predicted Answer: abandoned Isaac,
# True Answer: Conrad of Montferrat
#
# Example 155:
# Predicted Answer:
# True Answer: silver
#
# Example 156:
# Predicted Answer: with
# True Answer: Guy de Lusignan
#
# Example 157:
# Predicted Answer:
# True Answer:
#
# Example 158:
# Predicted Answer: him in
# True Answer:
#
# Example 159:
# Predicted Answer: the whole island,
# True Answer:
#
# Example 160:
# Predicted Answer: Normandy, Gascony and were later reinforced by Castilian colonists.
# True Answer: Africa
#
# Example 161:
# Predicted Answer:
# True Answer:
#
# Example 162:
# Predicted Answer:
# True Answer:
#
# Example 163:
# Predicted Answer: islands to Enrique Pérez de Guzmán, 2nd Count de Niebla.
# True Answer: Bethencourt
#
# Example 164:
# Predicted Answer:
# True Answer: Enrique Pérez de Guzmán
#
# Example 165:
# Predicted Answer:
# True Answer: Maciot de Bethencourt
#
# Example 166:
# Predicted Answer:
# True Answer:
#
# Example 167:
# Predicted Answer: III of
# True Answer:
#
# Example 168:
# Predicted Answer:
# True Answer: Channel Islands
#
# Example 169:
# Predicted Answer: The
# True Answer: two
#
# Example 170:
# Predicted Answer: by two
# True Answer:
#
# Example 171:
# Predicted Answer:
# True Answer:
#
# Example 172:
# Predicted Answer:
# True Answer:
#
# Example 173:
# Predicted Answer: Norman
# True Answer: Romanesque
#
# Example 174:
# Predicted Answer:
# True Answer: rounded
#
# Example 175:
# Predicted Answer:
# True Answer:
#
# Example 176:
# Predicted Answer: of
# True Answer: Early Gothic
#
# Example 177:
# Predicted Answer:
# True Answer: Anglo-Saxon
#
# Example 178:
# Predicted Answer:
# True Answer: Sicily
#
# Example 179:
# Predicted Answer: the
# True Answer:
#
# Example 180:
# Predicted Answer:
# True Answer:
#
# Example 181:
# Predicted Answer:
# True Answer:
#
# Example 182:
# Predicted Answer: channeled a pure
# True Answer: early 11th century
#
# Example 183:
# Predicted Answer: the 12th century, Normandy
# True Answer: dukes
#
# Example 184:
# Predicted Answer: 11th
# True Answer:
#
# Example 185:
# Predicted Answer: the so-called
# True Answer:
#
# Example 186:
# Predicted Answer: and Saint-Wandrille. These
# True Answer:
#
# Example 187:
# Predicted Answer: a programme of
# True Answer:
#
# Example 188:
# Predicted Answer:
# True Answer: 16th century
#
# Example 189:
# Predicted Answer:
# True Answer:
#
# Example 190:
# Predicted Answer: the
# True Answer:
#
# Example 191:
# Predicted Answer:
# True Answer: embroidery
#
# Example 192:
# Predicted Answer:
# True Answer: Bayeux Tapestry
#
# Example 193:
# Predicted Answer:
# True Answer: Odo
#
# Example 194:
# Predicted Answer: It was
# True Answer:
#
# Example 195:
# Predicted Answer:
# True Answer:
#
# Example 196:
# Predicted Answer:
# True Answer: mosaics
#
# Example 197:
# Predicted Answer: heavily on
# True Answer:
#
# Example 198:
# Predicted Answer: continued under Norman domination.
# True Answer:
#
# Example 199:
# Predicted Answer: is of Arab craftsmanship with Arabic inscriptions. Many churches preserve sculptured fonts,
# True Answer:
#
# Example 200:
# Predicted Answer: staff, around which neumes were oriented, was first developed and taught in the 11th century. Under the German abbot Isembard, La
# True Answer: 11th
#
# Example 201:
# Predicted Answer: centres
# True Answer: William of Volpiano and John of Ravenna
#
# Example 202:
# Predicted Answer:
# True Answer:
#
# Example 203:
# Predicted Answer: Abbey and Saint-Evroul Abbey were
# True Answer:
#
# Example 204:
# Predicted Answer:
# True Answer: southern Italy
#
# Example 205:
# Predicted Answer:
# True Answer: Latin monastery at Sant'Eufemia.
#
# Example 206:
# Predicted Answer: several monks of
# True Answer: Robert Guiscard
#
# Example 207:
# Predicted Answer:
# True Answer: singing
#
# Example 208:
# Predicted Answer:
# True Answer:
#
# Example 209:
# Predicted Answer: be a task that is in principle amenable to
# True Answer: Computational complexity theory
#
# Example 210:
# Predicted Answer:
# True Answer: inherent difficulty
#
# Example 211:
# Predicted Answer:
# True Answer: computational problems
#
# Example 212:
# Predicted Answer:
# True Answer:
#
# Example 213:
# Predicted Answer:
# True Answer:
#
# Example 214:
# Predicted Answer:
# True Answer:
#
# Example 215:
# Predicted Answer: classes to each
# True Answer:
#
# Example 216:
# Predicted Answer:
# True Answer:
#
# Example 217:
# Predicted Answer: the amount of resources needed to solve them, such
# True Answer: if its solution requires significant resources
#
# Example 218:
# Predicted Answer: The theory formalizes this intuition, by introducing mathematical models of computation to study these problems and quantifying the amount of resources needed to solve them, such as time and storage. Other complexity
# True Answer: mathematical models of computation
#
# Example 219:
# Predicted Answer:
# True Answer: time and storage
#
# Example 220:
# Predicted Answer:
# True Answer: number of gates in a circuit
#
# Example 221:
# Predicted Answer: the amount of communication (used in communication complexity), the number of gates in a circuit (used in circuit complexity) and the number of processors (used
# True Answer: determine the practical limits on what computers can and cannot do
#
# Example 222:
# Predicted Answer:
# True Answer:
#
# Example 223:
# Predicted Answer: measures are also used, such as the amount of communication (used in communication complexity), the number of gates in a circuit (used in circuit complexity) and the number of processors (used in parallel computing). One of the roles of computational complexity theory is to determine the practical limits on what computers can and cannot do.
# True Answer:
#
# Example 224:
# Predicted Answer: time and storage.
# True Answer:
#
# Example 225:
# Predicted Answer: (used in
# True Answer:
#
# Example 226:
# Predicted Answer: theory formalizes this intuition, by
# True Answer:
#
# Example 227:
# Predicted Answer:
# True Answer: analysis of algorithms and computability theory
#
# Example 228:
# Predicted Answer:
# True Answer: analysis of algorithms
#
# Example 229:
# Predicted Answer: and
# True Answer: computational complexity theory
#
# Example 230:
# Predicted Answer:
# True Answer: computability theory
#
# Example 231:
# Predicted Answer: of resources needed by
# True Answer:
#
# Example 232:
# Predicted Answer: all possible algorithms that could be used to solve the same problem. More precisely, it tries to classify
# True Answer:
#
# Example 233:
# Predicted Answer:
# True Answer:
#
# Example 234:
# Predicted Answer:
# True Answer:
#
# Example 235:
# Predicted Answer: Closely
# True Answer:
#
# Example 236:
# Predicted Answer:
# True Answer: problem instance
#
# Example 237:
# Predicted Answer:
# True Answer: the problem
#
# Example 238:
# Predicted Answer:
# True Answer: concrete
#
# Example 239:
# Predicted Answer: problem is
# True Answer: instances
#
# Example 240:
# Predicted Answer:
# True Answer: solution
#
# Example 241:
# Predicted Answer: a decision problem.
# True Answer:
#
# Example 242:
# Predicted Answer: the problem, and the
# True Answer:
#
# Example 243:
# Predicted Answer: The instance is
# True Answer:
#
# Example 244:
# Predicted Answer:
# True Answer:
#
# Example 245:
# Predicted Answer: every instance. The input string for a computational problem is referred to as a problem instance, and should not be confused with the problem itself. In computational complexity theory, a problem refers to the abstract question to be solved. In contrast, an instance of this problem is a rather concrete utterance, which can serve as the input for a decision problem. For example, consider the problem of primality testing. The instance is a number (e.g. 15) and the solution is "yes" if the number is prime and
# True Answer:
#
# Example 246:
# Predicted Answer: the problem,
# True Answer: 2000
#
# Example 247:
# Predicted Answer: answer
# True Answer: round trip through all sites in Milan
#
# Example 248:
# Predicted Answer:
# True Answer: computational problems
#
# Example 249:
# Predicted Answer: all sites in Milan whose total length is at most
# True Answer:
#
# Example 250:
# Predicted Answer:
# True Answer:
#
# Example 251:
# Predicted Answer: instances of the problem,
# True Answer:
#
# Example 252:
# Predicted Answer: asking for
# True Answer:
#
# Example 253:
# Predicted Answer:
# True Answer: problem instance
#
# Example 254:
# Predicted Answer:
# True Answer: binary alphabet
#
# Example 255:
# Predicted Answer:
# True Answer: bitstrings
#
# Example 256:
# Predicted Answer: in a
# True Answer: binary notation
#
# Example 257:
# Predicted Answer: a real-world
# True Answer: adjacency matrices
#
# Example 258:
# Predicted Answer:
# True Answer:
#
# Example 259:
# Predicted Answer: be suitably encoded. For example, integers can
# True Answer:
#
# Example 260:
# Predicted Answer:
# True Answer:
#
# Example 261:
# Predicted Answer:
# True Answer:
#
# Example 262:
# Predicted Answer: adjacency matrices, or by
# True Answer:
#
# Example 263:
# Predicted Answer: complexity theory.
# True Answer: Decision problems
#
# Example 264:
# Predicted Answer: are those instances whose output is no. The objective is to decide, with the aid of an algorithm, whether a given input string is a member of the formal language under consideration. If the algorithm deciding this problem returns the answer yes, the
# True Answer: yes or no
#
# Example 265:
# Predicted Answer:
# True Answer: 1 or 0
#
# Example 266:
# Predicted Answer: the algorithm deciding
# True Answer: yes
#
# Example 267:
# Predicted Answer: said to reject the
# True Answer: yes
#
# Example 268:
# Predicted Answer:
# True Answer:
#
# Example 269:
# Predicted Answer: is
# True Answer:
#
# Example 270:
# Predicted Answer:
# True Answer:
#
# Example 271:
# Predicted Answer: under consideration.
# True Answer:
#
# Example 272:
# Predicted Answer:
# True Answer:
#
# Example 273:
# Predicted Answer: all connected
# True Answer: arbitrary graph
#
# Example 274:
# Predicted Answer: is the following.
# True Answer: formal language
#
# Example 275:
# Predicted Answer:
# True Answer: how graphs are encoded as binary strings
#
# Example 276:
# Predicted Answer: of all
# True Answer:
#
# Example 277:
# Predicted Answer:
# True Answer:
#
# Example 278:
# Predicted Answer:
# True Answer:
#
# Example 279:
# Predicted Answer:
# True Answer:
#
# Example 280:
# Predicted Answer:
# True Answer: a computational problem
#
# Example 281:
# Predicted Answer:
# True Answer: a single output
#
# Example 282:
# Predicted Answer:
# True Answer: A function problem
#
# Example 283:
# Predicted Answer:
# True Answer: the integer factorization problem
#
# Example 284:
# Predicted Answer:
# True Answer: complex
#
# Example 285:
# Predicted Answer:
# True Answer:
#
# Example 286:
# Predicted Answer:
# True Answer:
#
# Example 287:
# Predicted Answer: that of
# True Answer:
#
# Example 288:
# Predicted Answer: or no. Notable
# True Answer:
#
# Example 289:
# Predicted Answer: is, it isn't just yes or no. Notable examples include the traveling salesman problem and the integer factorization problem.
# True Answer:
#
# Example 290:
# Predicted Answer: be recast as decision
# True Answer: decision problems
#
# Example 291:
# Predicted Answer:
# True Answer: set of triples
#
# Example 292:
# Predicted Answer:
# True Answer:
#
# Example 293:
# Predicted Answer: For example, the
# True Answer:
#
# Example 294:
# Predicted Answer: c) such
# True Answer:
#
# Example 295:
# Predicted Answer:
# True Answer: how much time the best algorithm requires to solve the problem
#
# Example 296:
# Predicted Answer: to
# True Answer: the instance
#
# Example 297:
# Predicted Answer:
# True Answer: as a function of the size of the instance
#
# Example 298:
# Predicted Answer:
# True Answer: bits
#
# Example 299:
# Predicted Answer: as a function of the size of the instance. This is usually taken to be the size
# True Answer: an increase in the input size
#
# Example 300:
# Predicted Answer: it take
# True Answer:
#
# Example 301:
# Predicted Answer:
# True Answer:
#
# Example 302:
# Predicted Answer: solve the problem. However,
# True Answer:
#
# Example 303:
# Predicted Answer: see how much
# True Answer:
#
# Example 304:
# Predicted Answer:
# True Answer:
#
# Example 305:
# Predicted Answer: be
# True Answer: Cobham's thesis
#
# Example 306:
# Predicted Answer: the time taken on different inputs of the same size can be different, the worst-case time complexity T(n) is defined to be the maximum time taken over all inputs of size n. If T(n) is a polynomial in n, then the algorithm is said to be a polynomial time algorithm. Cobham's thesis says that a problem can be solved with a feasible amount of resources if it admits a polynomial time algorithm.
# True Answer: the time taken
#
# Example 307:
# Predicted Answer:
# True Answer: worst-case time complexity
#
# Example 308:
# Predicted Answer: If
# True Answer: T(n)
#
# Example 309:
# Predicted Answer:
# True Answer: polynomial time algorithm
#
# Example 310:
# Predicted Answer: as a function of n. Since the time taken on different inputs of the same size can be different, the worst-case time complexity T(n) is defined to be the maximum time taken over all inputs of size n. If T(n) is a polynomial in n, then the algorithm is said to be a polynomial time algorithm. Cobham's thesis says that a problem can be solved with a feasible amount of resources if it admits a polynomial time algorithm.
# True Answer:
#
# Example 311:
# Predicted Answer:
# True Answer:
#
# Example 312:
# Predicted Answer: inputs of size
# True Answer:
#
# Example 313:
# Predicted Answer: it admits a polynomial
# True Answer:
#
# Example 314:
# Predicted Answer: that a
# True Answer:
#
# Example 315:
# Predicted Answer: algorithm, there exists a Turing machine that solves the problem. Indeed, this is the statement of the Church–Turing thesis. Furthermore, it
# True Answer: A Turing machine
#
# Example 316:
# Predicted Answer: and are
# True Answer: an algorithm
#
# Example 317:
# Predicted Answer: Church–Turing
# True Answer: the Turing machine
#
# Example 318:
# Predicted Answer: of
# True Answer: symbols
#
# Example 319:
# Predicted Answer: are not intended
# True Answer:
#
# Example 320:
# Predicted Answer: easy
# True Answer:
#
# Example 321:
# Predicted Answer:
# True Answer:
#
# Example 322:
# Predicted Answer: but rather
# True Answer:
#
# Example 323:
# Predicted Answer: non-determinism is that the Turing machine
# True Answer: A deterministic Turing machine
#
# Example 324:
# Predicted Answer: bits are called randomized algorithms. A non-deterministic Turing
# True Answer: rules
#
# Example 325:
# Predicted Answer: the problem in
# True Answer: A probabilistic Turing machine
#
# Example 326:
# Predicted Answer: to determine its future actions.
# True Answer: A non-deterministic Turing machine
#
# Example 327:
# Predicted Answer: efficiently. Algorithms that use random
# True Answer: randomized algorithms
#
# Example 328:
# Predicted Answer: randomized algorithms. A non-deterministic Turing machine is a deterministic Turing machine with an added feature of non-determinism, which allows a Turing machine to have multiple possible future actions from a given state. One way to view non-determinism is that the Turing machine branches into many possible computational paths at each step, and if it solves the problem in any of these branches, it is said to have solved the problem. Clearly, this model is not meant to be a physically realizable model, it is just a
# True Answer:
#
# Example 329:
# Predicted Answer:
# True Answer:
#
# Example 330:
# Predicted Answer: machine is a deterministic Turing machine with an added feature of non-determinism, which allows a Turing machine to have
# True Answer:
#
# Example 331:
# Predicted Answer: deterministic Turing machine
# True Answer:
#
# Example 332:
# Predicted Answer: determine its future actions. A
# True Answer:
#
# Example 333:
# Predicted Answer:
# True Answer: complexity classes
#
# Example 334:
# Predicted Answer:
# True Answer: time or space
#
# Example 335:
# Predicted Answer: symmetric
# True Answer: probabilistic Turing machines, non-deterministic Turing machines
#
# Example 336:
# Predicted Answer: as deterministic Turing machines, probabilistic
# True Answer:
#
# Example 337:
# Predicted Answer: machines, quantum Turing machines, symmetric Turing machines and alternating Turing machines. They are all equally powerful in principle, but when resources
# True Answer:
#
# Example 338:
# Predicted Answer:
# True Answer:
#
# Example 339:
# Predicted Answer:
# True Answer:
#
# Example 340:
# Predicted Answer: memory consumption of these alternate models may
# True Answer: random access machines
#
# Example 341:
# Predicted Answer:
# True Answer: computational power
#
# Example 342:
# Predicted Answer:
# True Answer: time and memory
#
# Example 343:
# Predicted Answer:
# True Answer: the machines operate deterministically
#
# Example 344:
# Predicted Answer: converted to another
# True Answer:
#
# Example 345:
# Predicted Answer:
# True Answer:
#
# Example 346:
# Predicted Answer: and memory consumption of these alternate models may vary. What all these
# True Answer:
#
# Example 347:
# Predicted Answer:
# True Answer:
#
# Example 348:
# Predicted Answer: to do
# True Answer: non-deterministic
#
# Example 349:
# Predicted Answer:
# True Answer: unusual resources
#
# Example 350:
# Predicted Answer: a computational model
# True Answer: mathematical models
#
# Example 351:
# Predicted Answer:
# True Answer: time
#
# Example 352:
# Predicted Answer: non-deterministic
# True Answer:
#
# Example 353:
# Predicted Answer:
# True Answer:
#
# Example 354:
# Predicted Answer: machine is a computational
# True Answer:
#
# Example 355:
# Predicted Answer: machine has very
# True Answer:
#
# Example 356:
# Predicted Answer: we want to analyze, so that non-deterministic time is a very important
# True Answer:
#
# Example 357:
# Predicted Answer: f(n) if
# True Answer: state transitions
#
# Example 358:
# Predicted Answer: as the deterministic Turing machine is used. The
# True Answer: difficulty
#
# Example 359:
# Predicted Answer:
# True Answer: DTIME(f(n))
#
# Example 360:
# Predicted Answer: the
# True Answer: time
#
# Example 361:
# Predicted Answer:
# True Answer:
#
# Example 362:
# Predicted Answer: deterministic
# True Answer:
#
# Example 363:
# Predicted Answer:
# True Answer:
#
# Example 364:
# Predicted Answer: their difficulty,
# True Answer:
#
# Example 365:
# Predicted Answer: if the time required by M on each input of length n is at
# True Answer:
#
# Example 366:
# Predicted Answer:
# True Answer: complexity resources
#
# Example 367:
# Predicted Answer: complexity measures used in complexity
# True Answer: computational resource
#
# Example 368:
# Predicted Answer: Analogous definitions can be made for space requirements. Although time and space are the most well-known complexity resources, any complexity measure can be viewed as a computational resource. Complexity measures are very generally defined by the Blum complexity axioms. Other complexity measures used in complexity theory include communication complexity, circuit complexity, and decision tree complexity.
# True Answer: Blum complexity axioms
#
# Example 369:
# Predicted Answer:
# True Answer: Complexity measures
#
# Example 370:
# Predicted Answer:
# True Answer: Complexity measures
#
# Example 371:
# Predicted Answer:
# True Answer:
#
# Example 372:
# Predicted Answer:
# True Answer:
#
# Example 373:
# Predicted Answer:
# True Answer:
#
# Example 374:
# Predicted Answer:
# True Answer:
#
# Example 375:
# Predicted Answer:
# True Answer:
#
# Example 376:
# Predicted Answer: following complexities:
# True Answer: best, worst and average
#
# Example 377:
# Predicted Answer:
# True Answer: complexity measure
#
# Example 378:
# Predicted Answer: Since some inputs
# True Answer: time
#
# Example 379:
# Predicted Answer:
# True Answer: inputs
#
# Example 380:
# Predicted Answer:
# True Answer:
#
# Example 381:
# Predicted Answer:
# True Answer:
#
# Example 382:
# Predicted Answer:
# True Answer:
#
# Example 383:
# Predicted Answer: others, we define the following complexities:
# True Answer:
#
# Example 384:
# Predicted Answer:
# True Answer: deterministic sorting algorithm quicksort
#
# Example 385:
# Predicted Answer: input.
# True Answer: worst-case
#
# Example 386:
# Predicted Answer: problem
# True Answer: O(n2)
#
# Example 387:
# Predicted Answer: also needing O(n log n) time.
# True Answer:
#
# Example 388:
# Predicted Answer: when each pivoting divides the
# True Answer:
#
# Example 389:
# Predicted Answer:
# True Answer:
#
# Example 390:
# Predicted Answer: the input.
# True Answer:
#
# Example 391:
# Predicted Answer: The
# True Answer:
#
# Example 392:
# Predicted Answer: consumption), one is interested
# True Answer: the most efficient algorithm
#
# Example 393:
# Predicted Answer: most T(n). However, proving
# True Answer: analysis of algorithms
#
# Example 394:
# Predicted Answer: usually taken to be its worst-case
# True Answer: lower bounds
#
# Example 395:
# Predicted Answer:
# True Answer: upper bound
#
# Example 396:
# Predicted Answer: a statement about all possible algorithms
# True Answer: all possible algorithms
#
# Example 397:
# Predicted Answer: on
# True Answer:
#
# Example 398:
# Predicted Answer:
# True Answer:
#
# Example 399:
# Predicted Answer: upper
# True Answer:
#
# Example 400:
# Predicted Answer: future. To show a
# True Answer:
#
# Example 401:
# Predicted Answer: algorithm falls under the field of analysis of algorithms. To show an upper bound
# True Answer:
#
# Example 402:
# Predicted Answer:
# True Answer: big O notation
#
# Example 403:
# Predicted Answer:
# True Answer: constant factors and smaller terms
#
# Example 404:
# Predicted Answer: of the
# True Answer: T(n) = O(n2)
#
# Example 405:
# Predicted Answer:
# True Answer: the computational model
#
# Example 406:
# Predicted Answer: computational model used. For
# True Answer:
#
# Example 407:
# Predicted Answer: Upper
# True Answer:
#
# Example 408:
# Predicted Answer:
# True Answer:
#
# Example 409:
# Predicted Answer:
# True Answer:
#
# Example 410:
# Predicted Answer: this framework. Thus, a typical
# True Answer: complexity classes
#
# Example 411:
# Predicted Answer:
# True Answer: framework
#
# Example 412:
# Predicted Answer:
# True Answer: complicated definitions
#
# Example 413:
# Predicted Answer:
# True Answer:
#
# Example 414:
# Predicted Answer:
# True Answer:
#
# Example 415:
# Predicted Answer:
# True Answer:
#
# Example 416:
# Predicted Answer:
# True Answer:
#
# Example 417:
# Predicted Answer:
# True Answer: chosen machine model
#
# Example 418:
# Predicted Answer: binary string} can be solved in linear time on a multi-tape Turing machine, but necessarily requires quadratic time in the model of single-tape
# True Answer: linear time
#
# Example 419:
# Predicted Answer:
# True Answer: single-tape Turing machines
#
# Example 420:
# Predicted Answer: language
# True Answer: Cobham-Edmonds thesis
#
# Example 421:
# Predicted Answer:
# True Answer: complexity class P
#
# Example 422:
# Predicted Answer: string} can be solved
# True Answer:
#
# Example 423:
# Predicted Answer: that "the time complexities in any two reasonable and general models of computation are polynomially related" (Goldreich 2008, Chapter 1.2). This forms the basis for the
# True Answer:
#
# Example 424:
# Predicted Answer: problems solvable by
# True Answer:
#
# Example 425:
# Predicted Answer: a
# True Answer:
#
# Example 426:
# Predicted Answer: Turing machine, but
# True Answer:
#
# Example 427:
# Predicted Answer:
# True Answer: time or space
#
# Example 428:
# Predicted Answer: problems
# True Answer: bounding
#
# Example 429:
# Predicted Answer: manner
# True Answer: complexity classes
#
# Example 430:
# Predicted Answer:
# True Answer:
#
# Example 431:
# Predicted Answer:
# True Answer:
#
# Example 432:
# Predicted Answer:
# True Answer:
#
# Example 433:
# Predicted Answer:
# True Answer:
#
# Example 434:
# Predicted Answer: an
# True Answer: BPP, ZPP and RP
#
# Example 435:
# Predicted Answer: quantum Turing machines. #P is an important complexity class of counting problems (not decision problems). Classes like IP and AM are defined using Interactive proof
# True Answer: Boolean
#
# Example 436:
# Predicted Answer:
# True Answer: quantum
#
# Example 437:
# Predicted Answer: Turing
# True Answer: #P
#
# Example 438:
# Predicted Answer: and AM are defined
# True Answer: Interactive
#
# Example 439:
# Predicted Answer:
# True Answer:
#
# Example 440:
# Predicted Answer:
# True Answer:
#
# Example 441:
# Predicted Answer: NC, which are defined using Boolean circuits; and BQP and QMA, which are defined using quantum Turing machines. #P is an important complexity class of counting problems (not decision problems). Classes like IP and AM are defined using Interactive proof systems. ALL is the class of all decision problems.
# True Answer:
#
# Example 442:
# Predicted Answer:
# True Answer:
#
# Example 443:
# Predicted Answer: are defined using
# True Answer:
#
# Example 444:
# Predicted Answer: set inclusions, we can proceed to make
# True Answer: computation time
#
# Example 445:
# Predicted Answer: respective resources.
# True Answer: DTIME(n2)
#
# Example 446:
# Predicted Answer: the answer to such
# True Answer: time and space hierarchy theorems
#
# Example 447:
# Predicted Answer:
# True Answer: a proper hierarchy on the classes defined
#
# Example 448:
# Predicted Answer:
# True Answer: quantitative statements
#
# Example 449:
# Predicted Answer: hierarchy theorems respectively. They are called hierarchy theorems because they induce a proper
# True Answer:
#
# Example 450:
# Predicted Answer: They are called hierarchy theorems because they induce a proper hierarchy on the classes defined by constraining the respective resources. Thus there are pairs of complexity
# True Answer:
#
# Example 451:
# Predicted Answer: to make quantitative statements
# True Answer:
#
# Example 452:
# Predicted Answer: and space hierarchy
# True Answer:
#
# Example 453:
# Predicted Answer: theorems respectively. They are
# True Answer:
#
# Example 454:
# Predicted Answer:
# True Answer: time and space hierarchy theorems
#
# Example 455:
# Predicted Answer:
# True Answer: EXPTIME
#
# Example 456:
# Predicted Answer:
# True Answer: PSPACE
#
# Example 457:
# Predicted Answer:
# True Answer:
#
# Example 458:
# Predicted Answer:
# True Answer:
#
# Example 459:
# Predicted Answer:
# True Answer:
#
# Example 460:
# Predicted Answer: hierarchy
# True Answer:
#
# Example 461:
# Predicted Answer:
# True Answer: reduction
#
# Example 462:
# Predicted Answer: a reduction. A reduction is a transformation of one problem into another problem. It captures the informal notion of a problem being at least as difficult as another problem. For instance, if a problem X can be solved using an algorithm for Y, X
# True Answer: another problem
#
# Example 463:
# Predicted Answer:
# True Answer: reduces
#
# Example 464:
# Predicted Answer: of reductions, such
# True Answer: Karp reductions and Levin reductions
#
# Example 465:
# Predicted Answer:
# True Answer: the bound on the complexity of reductions
#
# Example 466:
# Predicted Answer: transformation of one problem into
# True Answer:
#
# Example 467:
# Predicted Answer:
# True Answer:
#
# Example 468:
# Predicted Answer: can be solved using
# True Answer:
#
# Example 469:
# Predicted Answer: the
# True Answer:
#
# Example 470:
# Predicted Answer: or log-space reductions.
# True Answer:
#
# Example 471:
# Predicted Answer: of
# True Answer: polynomial-time reduction
#
# Example 472:
# Predicted Answer: of multiplying two integers.
# True Answer: multiplying two integers
#
# Example 473:
# Predicted Answer:
# True Answer: polynomial time
#
# Example 474:
# Predicted Answer: done by giving
# True Answer: input
#
# Example 475:
# Predicted Answer: polynomial
# True Answer: multiplication
#
# Example 476:
# Predicted Answer: process takes polynomial time. For example, the problem
# True Answer:
#
# Example 477:
# Predicted Answer:
# True Answer:
#
# Example 478:
# Predicted Answer: difficult than multiplication, since
# True Answer:
#
# Example 479:
# Predicted Answer: squaring can be reduced to multiplication.
# True Answer:
#
# Example 480:
# Predicted Answer: to multiplication.
# True Answer:
#
# Example 481:
# Predicted Answer: the set
# True Answer: the type of reduction being used
#
# Example 482:
# Predicted Answer: a complexity class. A problem X is hard for a class of problems C if every problem in C can be reduced to X. Thus no problem in C is harder than X, since an algorithm for X allows us to solve any problem in C. Of course, the notion of hard problems depends on the type of reduction being used. For complexity classes larger
# True Answer: if every problem in C can be reduced to X
#
# Example 483:
# Predicted Answer:
# True Answer: solve any problem in C
#
# Example 484:
# Predicted Answer: polynomial-time reductions are commonly used. In particular, the set of problems
# True Answer: NP-hard
#
# Example 485:
# Predicted Answer: can be reduced
# True Answer:
#
# Example 486:
# Predicted Answer: since
# True Answer:
#
# Example 487:
# Predicted Answer:
# True Answer:
#
# Example 488:
# Predicted Answer: of reduction being used. For complexity classes
# True Answer:
#
# Example 489:
# Predicted Answer: the hardest problem in C. (Since many
# True Answer: NP-complete
#
# Example 490:
# Predicted Answer: in polynomial time would mean that P = NP.
# True Answer: NP
#
# Example 491:
# Predicted Answer: that they are the
# True Answer: there is no known polynomial-time solution
#
# Example 492:
# Predicted Answer: in C.)
# True Answer: NP
#
# Example 493:
# Predicted Answer: in
# True Answer:
#
# Example 494:
# Predicted Answer: problems in NP, in
# True Answer:
#
# Example 495:
# Predicted Answer:
# True Answer:
#
# Example 496:
# Predicted Answer: known
# True Answer:
#
# Example 497:
# Predicted Answer:
# True Answer: P
#
# Example 498:
# Predicted Answer: satisfiability problem, the Hamiltonian path
# True Answer: Cobham–Edmonds thesis
#
# Example 499:
# Predicted Answer:
# True Answer: NP
#
# Example 500:
# Predicted Answer: of
# True Answer: Boolean satisfiability problem
#
# Example 501:
# Predicted Answer:
# True Answer: Turing machines
#
# Example 502:
# Predicted Answer: The complexity
# True Answer:
#
# Example 503:
# Predicted Answer: the
# True Answer:
#
# Example 504:
# Predicted Answer:
# True Answer:
#
# Example 505:
# Predicted Answer: and the
# True Answer:
#
# Example 506:
# Predicted Answer:
# True Answer:
#
# Example 507:
# Predicted Answer: formal proofs of pure
# True Answer: more efficient solutions
#
# Example 508:
# Predicted Answer: of a solution. If the answer is yes, many important problems can
# True Answer: protein structure prediction
#
# Example 509:
# Predicted Answer: The
# True Answer: $1,000,000
#
# Example 510:
# Predicted Answer: prediction
# True Answer:
#
# Example 511:
# Predicted Answer:
# True Answer:
#
# Example 512:
# Predicted Answer:
# True Answer:
#
# Example 513:
# Predicted Answer:
# True Answer:
#
# Example 514:
# Predicted Answer: the ability to
# True Answer:
#
# Example 515:
# Predicted Answer:
# True Answer: Ladner
#
# Example 516:
# Predicted Answer: of the very few
# True Answer: NP-intermediate problems
#
# Example 517:
# Predicted Answer:
# True Answer: graph isomorphism problem
#
# Example 518:
# Predicted Answer: The graph isomorphism problem, the discrete logarithm
# True Answer:
#
# Example 519:
# Predicted Answer: that
# True Answer:
#
# Example 520:
# Predicted Answer:
# True Answer:
#
# Example 521:
# Predicted Answer: nor NP-complete.
# True Answer:
#
# Example 522:
# Predicted Answer: is in P, NP-complete,
# True Answer: The graph isomorphism problem
#
# Example 523:
# Predicted Answer: is
# True Answer: NP-complete
#
# Example 524:
# Predicted Answer: run
# True Answer: polynomial time hierarchy
#
# Example 525:
# Predicted Answer:
# True Answer: second level
#
# Example 526:
# Predicted Answer:
# True Answer: Laszlo Babai and Eugene Luks
#
# Example 527:
# Predicted Answer: known, but it
# True Answer:
#
# Example 528:
# Predicted Answer: P, NP-complete, or NP-intermediate. The answer is
# True Answer:
#
# Example 529:
# Predicted Answer: problem is
# True Answer:
#
# Example 530:
# Predicted Answer: The
# True Answer:
#
# Example 531:
# Predicted Answer: the polynomial hierarchy does not collapse
# True Answer:
#
# Example 532:
# Predicted Answer: in
# True Answer: The integer factorization problem
#
# Example 533:
# Predicted Answer: whether
# True Answer: k
#
# Example 534:
# Predicted Answer: the input has
# True Answer: modern cryptographic systems
#
# Example 535:
# Predicted Answer: such as the
# True Answer: the general number field sieve
#
# Example 536:
# Predicted Answer: will equal
# True Answer:
#
# Example 537:
# Predicted Answer: much about
# True Answer:
#
# Example 538:
# Predicted Answer: problem of deciding whether the input has a
# True Answer:
#
# Example 539:
# Predicted Answer: cryptographic systems, such as the
# True Answer:
#
# Example 540:
# Predicted Answer: a decision
# True Answer:
#
# Example 541:
# Predicted Answer:
# True Answer: suspected to be unequal
#
# Example 542:
# Predicted Answer:
# True Answer: P ⊆ NP ⊆ PP ⊆ PSPACE
#
# Example 543:
# Predicted Answer:
# True Answer: between P and PSPACE
#
# Example 544:
# Predicted Answer:
# True Answer: Proving that any of these classes are unequal
#
# Example 545:
# Predicted Answer:
# True Answer:
#
# Example 546:
# Predicted Answer: to
# True Answer:
#
# Example 547:
# Predicted Answer: P ⊆ NP
# True Answer:
#
# Example 548:
# Predicted Answer:
# True Answer:
#
# Example 549:
# Predicted Answer: For instance P ⊆
# True Answer:
#
# Example 550:
# Predicted Answer: NP
# True Answer: co-NP
#
# Example 551:
# Predicted Answer: co-NP; however,
# True Answer: reversed
#
# Example 552:
# Predicted Answer: not
# True Answer: not equal
#
# Example 553:
# Predicted Answer:
# True Answer: P is not equal to NP
#
# Example 554:
# Predicted Answer:
# True Answer:
#
# Example 555:
# Predicted Answer: been proven. It
# True Answer:
#
# Example 556:
# Predicted Answer: that NP is
# True Answer:
#
# Example 557:
# Predicted Answer:
# True Answer:
#
# Example 558:
# Predicted Answer:
# True Answer: L
#
# Example 559:
# Predicted Answer: Similarly,
# True Answer: strictly contained in P or equal to P
#
# Example 560:
# Predicted Answer: in
# True Answer: complexity classes
#
# Example 561:
# Predicted Answer: to
# True Answer: NL and NC
#
# Example 562:
# Predicted Answer:
# True Answer: if they are distinct or equal classes
#
# Example 563:
# Predicted Answer: be solved
# True Answer:
#
# Example 564:
# Predicted Answer:
# True Answer:
#
# Example 565:
# Predicted Answer:
# True Answer:
#
# Example 566:
# Predicted Answer:
# True Answer:
#
# Example 567:
# Predicted Answer: complexity classes between the two, such as NL and NC, and it is not known if they are distinct or equal
# True Answer:
#
# Example 568:
# Predicted Answer: their
# True Answer: intractable problems
#
# Example 569:
# Predicted Answer: computed
# True Answer: exponential-time algorithms
#
# Example 570:
# Predicted Answer: time), but which in practice take too long for their
# True Answer: NP-complete problems
#
# Example 571:
# Predicted Answer: Problems
# True Answer:
#
# Example 572:
# Predicted Answer: 4 ×
# True Answer:
#
# Example 573:
# Predicted Answer: which in practice take too long for their solutions to be useful, are known as intractable problems. In complexity theory, problems that lack
# True Answer:
#
# Example 574:
# Predicted Answer: those problems
# True Answer:
#
# Example 575:
# Predicted Answer: for more than
# True Answer:
#
# Example 576:
# Predicted Answer: Boolean satisfiability
# True Answer: Presburger arithmetic
#
# Example 577:
# Predicted Answer:
# True Answer: algorithms have been written
#
# Example 578:
# ...
# True Answer: economic
#
# Example 803:
# Predicted Answer:
# True Answer:
#
# Example 804:
# Predicted Answer: regions, each
# True Answer:
#
# Example 805:
# Predicted Answer:
# True Answer:
#
# Example 806:
# Predicted Answer:
# True Answer: 2010
#
# Example 807:
# Predicted Answer: 2000s as California's
# True Answer: high growth rates
#
# Example 808:
# Predicted Answer:
# True Answer: 10.0%
#
# Example 809:
# Predicted Answer: Area
# True Answer: tech-oriented
#
# Example 810:
# Predicted Answer: average of 10.0% in the
# True Answer: Greater Sacramento
#
# Example 811:
# Predicted Answer:
# True Answer:
#
# Example 812:
# Predicted Answer:
# True Answer:
#
# Example 813:
# Predicted Answer:
# True Answer:
#
# Example 814:
# Predicted Answer: an emerging Greater Sacramento region.
# True Answer:
#
# Example 815:
# Predicted Answer: million in
# True Answer: Metropolitan Statistical Areas
#
# Example 816:
# Predicted Answer: Marcos metropolitan area
# True Answer: two
#
# Example 817:
# Predicted Answer: to two extended metropolitan
# True Answer: five million
#
# Example 818:
# Predicted Answer: metropolitan areas
# True Answer: Southern Border Region
#
# Example 819:
# Predicted Answer: Southern
# True Answer: 17,786,419
#
# Example 820:
# Predicted Answer:
# True Answer:
#
# Example 821:
# Predicted Answer: Beach-Santa
# True Answer:
#
# Example 822:
# Predicted Answer: metropolitan area, Riverside-San Bernardino-Ontario metropolitan area, and Oxnard-Thousand Oaks-Ventura metropolitan area form Greater Los Angeles; while the El Centro metropolitan area and San Diego-Carlsbad-San
# True Answer:
#
# Example 823:
# Predicted Answer: region is home
# True Answer:
#
# Example 824:
# Predicted Answer:
# True Answer:
#
# Example 825:
# Predicted Answer: 100,000 in population. Many of southern California's most
# True Answer: Los Angeles
#
# Example 826:
# Predicted Answer:
# True Answer: 1.3 million
#
# Example 827:
# Predicted Answer: coast, with the exception
# True Answer: twelve
#
# Example 828:
# Predicted Answer:
# True Answer: 100,000
#
# Example 829:
# Predicted Answer: of
# True Answer: Riverside
#
# Example 830:
# Predicted Answer: of California
# True Answer:
#
# Example 831:
# Predicted Answer:
# True Answer:
#
# Example 832:
# Predicted Answer: 100,000 in
# True Answer:
#
# Example 833:
# Predicted Answer:
# True Answer:
#
# Example 834:
# Predicted Answer: States). In
# True Answer:
#
# Example 835:
# Predicted Answer: and
# True Answer: petroleum
#
# Example 836:
# Predicted Answer: as dominant, the
# True Answer: Hollywood
#
# Example 837:
# Predicted Answer: abundance of petroleum,
# True Answer: the housing bubble
#
# Example 838:
# Predicted Answer:
# True Answer: diverse
#
# Example 839:
# Predicted Answer:
# True Answer: heavily impacted
#
# Example 840:
# Predicted Answer: opposed to other regions where automobiles not nearly as dominant, the vast majority of transport runs on this fuel. Southern California is famous for tourism and Hollywood (film, television, and music). Other industries include software, automotive, ports, finance, tourism, biomedical, and regional logistics. The region was a leader in the housing bubble 2001–2007, and
# True Answer:
#
# Example 841:
# Predicted Answer: Southern
# True Answer:
#
# Example 842:
# Predicted Answer: runs on
# True Answer:
#
# Example 843:
# Predicted Answer: as
# True Answer:
#
# Example 844:
# Predicted Answer:
# True Answer: 1920s
#
# Example 845:
# Predicted Answer:
# True Answer: richest
#
# Example 846:
# Predicted Answer: military
# True Answer: cattle
#
# Example 847:
# Predicted Answer:
# True Answer: citrus
#
# Example 848:
# Predicted Answer:
# True Answer: aerospace
#
# Example 849:
# Predicted Answer: the 1920s,
# True Answer:
#
# Example 850:
# Predicted Answer: farmlands were turned
# True Answer:
#
# Example 851:
# Predicted Answer: cutbacks have had an impact,
# True Answer:
#
# Example 852:
# Predicted Answer: citrus were major
# True Answer:
#
# Example 853:
# Predicted Answer: Riverside.
# True Answer: business
#
# Example 854:
# Predicted Answer:
# True Answer: Central business districts
#
# Example 855:
# Predicted Answer:
# True Answer: South Coast Metro
#
# Example 856:
# Predicted Answer:
# True Answer:
#
# Example 857:
# Predicted Answer:
# True Answer:
#
# Example 858:
# Predicted Answer:
# True Answer:
#
# Example 859:
# Predicted Answer:
# True Answer: business
#
# Example 860:
# Predicted Answer:
# True Answer: Los Angeles Area
#
# Example 861:
# Predicted Answer: including the Downtown
# True Answer: San Fernando Valley
#
# Example 862:
# Predicted Answer:
# True Answer: Los Angeles
#
# Example 863:
# Predicted Answer:
# True Answer:
#
# Example 864:
# Predicted Answer:
# True Answer:
#
# Example 865:
# Predicted Answer:
# True Answer:
#
# Example 866:
# Predicted Answer:
# True Answer: business
#
# Example 867:
# Predicted Answer:
# True Answer: Riverside
#
# Example 868:
# Predicted Answer:
# True Answer: Hospitality Business/Financial Centre
#
# Example 869:
# Predicted Answer: and
# True Answer:
#
# Example 870:
# Predicted Answer:
# True Answer:
#
# Example 871:
# Predicted Answer:
# True Answer: Orange
#
# Example 872:
# Predicted Answer: Santa Ana,
# True Answer: University of California, Irvine
#
# Example 873:
# Predicted Answer:
# True Answer: West Irvine
#
# Example 874:
# Predicted Answer: California, Irvine. West Irvine includes the Irvine Tech Center and
# True Answer: South Coast Metro
#
# Example 875:
# Predicted Answer:
# True Answer: rapidly
#
# Example 876:
# Predicted Answer: the Irvine business centers of The Irvine Spectrum, West Irvine, and
# True Answer:
#
# Example 877:
# Predicted Answer: the Irvine business centers of The Irvine Spectrum, West Irvine, and international corporations headquartered at the University of California, Irvine.
# True Answer:
#
# Example 878:
# Predicted Answer:
# True Answer:
#
# Example 879:
# Predicted Answer:
# True Answer:
#
# Example 880:
# Predicted Answer:
# True Answer: Downtown San Diego
#
# Example 881:
# Predicted Answer:
# True Answer: Northern San Diego
#
# Example 882:
# Predicted Answer: is filled with business districts. These include Carmel Valley, Del Mar
# True Answer: North County
#
# Example 883:
# Predicted Answer:
# True Answer: San Diego
#
# Example 884:
# Predicted Answer:
# True Answer:
#
# Example 885:
# Predicted Answer: Rancho
# True Answer:
#
# Example 886:
# Predicted Answer: Mar Heights,
# True Answer:
#
# Example 887:
# Predicted Answer:
# True Answer: Los Angeles International Airport
#
# Example 888:
# Predicted Answer:
# True Answer: passenger volume
#
# Example 889:
# Predicted Answer: United States by passenger volume (see World's busiest airports by passenger traffic) and the third by international passenger volume (see Busiest airports in the United States by international passenger traffic); San Diego International Airport the busiest single runway airport in the world; Van Nuys Airport, the world's busiest general aviation airport; major commercial airports at Orange
# True Answer: third
#
# Example 890:
# Predicted Answer: Busiest airports in
# True Answer: San Diego International Airport
#
# Example 891:
# Predicted Answer: in the United States by passenger volume (see World's busiest airports by passenger traffic) and the third by international passenger volume (see Busiest airports in the United States by international passenger traffic); San Diego International Airport the busiest single runway airport in
# True Answer: Van Nuys Airport
#
# Example 892:
# Predicted Answer:
# True Answer:
#
# Example 893:
# Predicted Answer:
# True Answer:
#
# Example 894:
# Predicted Answer: Nuys Airport,
# True Answer:
#
# Example 895:
# Predicted Answer: the world;
# True Answer:
#
# Example 896:
# Predicted Answer:
# True Answer: Metrolink
#
# Example 897:
# Predicted Answer: Angeles, Ventura, San
# True Answer: seven
#
# Example 898:
# Predicted Answer:
# True Answer: Six
#
# Example 899:
# Predicted Answer:
# True Answer: Orange
#
# Example 900:
# Predicted Answer:
# True Answer:
#
# Example 901:
# Predicted Answer: out of Downtown Los Angeles, connecting Los Angeles, Ventura, San Bernardino, Riverside, Orange, and San Diego counties with the other line connecting San Bernardino, Riverside, and Orange counties directly.
# True Answer:
#
# Example 902:
# Predicted Answer:
# True Answer:
#
# Example 903:
# Predicted Answer:
# True Answer: Port of Los Angeles
#
# Example 904:
# Predicted Answer: of Long Beach, the United
# True Answer: Port of San Diego
#
# Example 905:
# Predicted Answer: busiest
# True Answer: Southern
#
# Example 906:
# Predicted Answer:
# True Answer:
#
# Example 907:
# Predicted Answer:
# True Answer:
#
# Example 908:
# Predicted Answer:
# True Answer:
#
# Example 909:
# Predicted Answer: of
# True Answer:
#
# Example 910:
# Predicted Answer: institutions such as
# True Answer: The Tech Coast
#
# Example 911:
# Predicted Answer: such as
# True Answer: research
#
# Example 912:
# Predicted Answer: technology and industrial base as well as its multitude of prestigious and world-renowned research universities and other public and private institutions. Amongst these include 5 University of California campuses (Irvine, Los Angeles, Riverside, Santa Barbara, and San Diego); 12 California State University campuses (Bakersfield, Channel Islands, Dominguez Hills, Fullerton, Los Angeles, Long Beach, Northridge, Pomona, San Bernardino, San Diego, San Marcos, and San Luis Obispo); and private institutions such as the California Institute of Technology, Chapman University, the Claremont Colleges (Claremont McKenna College, Harvey Mudd College, Pitzer College, Pomona College, and Scripps College), Loma Linda University, Loyola Marymount University, Occidental College, Pepperdine University, University of Redlands, University of San Diego, and the University of Southern California.
# True Answer: private
#
# Example 913:
# Predicted Answer: Bernardino, San Diego, San Marcos, and San
# True Answer: 5
#
# Example 914:
# Predicted Answer: and other public and private institutions. Amongst these include
# True Answer: 12
#
# Example 915:
# Predicted Answer: The Tech Coast is a moniker that has gained use as a descriptor for the region's diversified technology and industrial base as well as its multitude of prestigious and world-renowned research universities and other public and private institutions. Amongst these include 5 University of California campuses (Irvine, Los Angeles, Riverside, Santa Barbara, and San Diego); 12
# True Answer:
#
# Example 916:
# Predicted Answer: College, Pepperdine
# True Answer:
#
# Example 917:
# Predicted Answer: and private institutions. Amongst
# True Answer:
#
# Example 918:
# Predicted Answer: San Bernardino, San
# True Answer:
#
# Example 919:
# Predicted Answer: Chapman University, the
# True Answer:
#
# Example 920:
# Predicted Answer:
# True Answer: NFL
#
# Example 921:
# Predicted Answer: of
# True Answer: NBA
#
# Example 922:
# Predicted Answer:
# True Answer: MLB
#
# Example 923:
# Predicted Answer: and MLS (LA Galaxy).
# True Answer: Los Angeles Kings
#
# Example 924:
# Predicted Answer: (Los Angeles Lakers, Los
# True Answer: LA Galaxy
#
# Example 925:
# Predicted Answer: Anaheim,
# True Answer:
#
# Example 926:
# Predicted Answer:
# True Answer:
#
# Example 927:
# Predicted Answer:
# True Answer:
#
# Example 928:
# Predicted Answer:
# True Answer:
#
# Example 929:
# Predicted Answer: Diego Padres); NHL (Los Angeles Kings, Anaheim Ducks); and MLS (LA Galaxy).
# True Answer:
#
# Example 930:
# Predicted Answer:
# True Answer: Chivas USA
#
# Example 931:
# Predicted Answer:
# True Answer: two
#
# Example 932:
# Predicted Answer: were local rivals. However, Chivas were suspended
# True Answer: 2014
#
# Example 933:
# Predicted Answer: and were
# True Answer: StubHub Center
#
# Example 934:
# Predicted Answer:
# True Answer: 2018
#
# Example 935:
# Predicted Answer:
# True Answer:
#
# Example 936:
# Predicted Answer:
# True Answer:
#
# Example 937:
# Predicted Answer:
# True Answer:
#
# Example 938:
# Predicted Answer: were suspended following the 2014 MLS season, with a second MLS team
# True Answer:
#
# Example 939:
# Predicted Answer:
# True Answer: College
#
# Example 940:
# Predicted Answer:
# True Answer: UCLA
#
# Example 941:
# Predicted Answer:
# True Answer: Trojans
#
# Example 942:
# Predicted Answer:
# True Answer: Pac-12
#
# Example 943:
# Predicted Answer:
# True Answer: Division I
#
# Example 944:
# Predicted Answer:
# True Answer:
#
# Example 945:
# Predicted Answer: longtime rivalry between
# True Answer:
#
# Example 946:
# Predicted Answer:
# True Answer:
#
# Example 947:
# Predicted Answer:
# True Answer: Rugby
#
# Example 948:
# Predicted Answer: an official
# True Answer: high school
#
# Example 949:
# Predicted Answer:
# True Answer: an official school sport
#
# Example 950:
# Predicted Answer:
# True Answer:
#
# Example 951:
# Predicted Answer: The United Kingdom
# True Answer: BSkyB
#
# Example 952:
# Predicted Answer:
# True Answer: BSkyB
#
# Example 953:
# Predicted Answer: operations also changed the
# True Answer: 2014
#
# Example 954:
# Predicted Answer: its name to
# True Answer: Sky plc
#
# Example 955:
# Predicted Answer: Formed
# True Answer: Sky UK Limited
#
# Example 956:
# Predicted Answer:
# True Answer:
#
# Example 957:
# Predicted Answer:
# True Answer:
#
# Example 958:
# Predicted Answer: still trading
# True Answer:
#
# Example 959:
# Predicted Answer: The United Kingdom operations also changed the company name from British Sky Broadcasting Limited to Sky UK Limited, still
# True Answer:
#
# Example 960:
# Predicted Answer: a majority
# True Answer:
#
# Example 961:
# Predicted Answer: deemed
# True Answer: 2006
#
# Example 962:
# Predicted Answer: from the 2007–08 season. In May 2006, the Irish broadcaster Setanta Sports was awarded two of the six Premier League packages that the
# True Answer: two
#
# Example 963:
# Predicted Answer: had expected to pay. The
# True Answer: Sky
#
# Example 964:
# Predicted Answer: monopoly came
# True Answer: £1.3bn
#
# Example 965:
# Predicted Answer: of
# True Answer:
#
# Example 966:
# Predicted Answer: awarded two of the
# True Answer:
#
# Example 967:
# Predicted Answer: to be £1bn
# True Answer:
#
# Example 968:
# Predicted Answer: the dropping of the 3D channel.
# True Answer:
#
# Example 969:
# Predicted Answer: £1bn more
# True Answer:
#
# Example 970:
# Predicted Answer: 31 October 2005, which was itself later
# True Answer: ONdigital
#
# Example 971:
# Predicted Answer:
# True Answer: Freeview
#
# Example 972:
# Predicted Answer:
# True Answer: three
#
# Example 973:
# Predicted Answer: platform: Sky News, Sky Three, and Sky
# True Answer: Sky Three
#
# Example 974:
# Predicted Answer: Grid Wireless. Prior
# True Answer: Pick TV
#
# Example 975:
# Predicted Answer:
# True Answer:
#
# Example 976:
# Predicted Answer:
# True Answer:
#
# Example 977:
# Predicted Answer:
# True Answer:
#
# Example 978:
# Predicted Answer: as 'Pick TV'
# True Answer:
#
# Example 979:
# Predicted Answer:
# True Answer:
#
# Example 980:
# Predicted Answer: new TV
# True Answer: Sky+ PVR
#
# Example 981:
# Predicted Answer: Box, limited the
# True Answer: September 2007
#
# Example 982:
# Predicted Answer: service; waiving the charge for subscribers whose package included two or more premium channels. This changed as from 1 July 2007, and now customers that have Sky+ and subscribe to any BSkyB subscription package get Sky+ included at no extra charge. Customers that do not subscribe to
# True Answer: monthly fee
#
# Example 983:
# Predicted Answer: get Sky+ included at
# True Answer: January 2010
#
# Example 984:
# Predicted Answer:
# True Answer: Sky+HD Box
#
# Example 985:
# Predicted Answer: BSkyB subscription package get
# True Answer:
#
# Example 986:
# Predicted Answer: Multiroom upgrade
# True Answer:
#
# Example 987:
# Predicted Answer: PVR with
# True Answer:
#
# Example 988:
# Predicted Answer: package included two
# True Answer:
#
# Example 989:
# Predicted Answer: the
# True Answer:
#
# Example 990:
# Predicted Answer: tight controls over
# True Answer: VideoGuard
#
# Example 991:
# Predicted Answer: to the Personal video recorder
# True Answer: NDS
#
# Example 992:
# Predicted Answer: authority over all
# True Answer: Cisco Systems
#
# Example 993:
# Predicted Answer: as all the others. This extends to the Personal video
# True Answer: BSkyB
#
# Example 994:
# Predicted Answer: they are not available as stand-alone DVB CAMs (conditional-access modules). BSkyB has design authority over
# True Answer: Sky+
#
# Example 995:
# Predicted Answer: as all the
# True Answer:
#
# Example 996:
# Predicted Answer:
# True Answer:
#
# Example 997:
# Predicted Answer: all
# True Answer:
#
# Example 998:
# Predicted Answer:
# True Answer:
#
# Example 999:
# Predicted Answer: receivers, though designed and built by different manufacturers, must conform to the
# True Answer:
#
# Example 1000:
# Predicted Answer: HD
# True Answer: 2007
#
# Average F1 Score: 0.0090
